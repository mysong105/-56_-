# %%
from __future__ import absolute_import, division, print_function, unicode_literals


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, Conv2D,MaxPooling2D,concatenate,Input
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential

# Import deep learning resources from Keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D
from keras.layers import Flatten, Dense
from keras.layers.normalization import BatchNormalization


# Build a CNN architecture

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))


model.add(Dense(30))


# Summarize the model
model.summary()
# Out:
# C:\Users\myson\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\myson\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\myson\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,161,630
# Trainable params: 1,161,630
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
from keras.optimizers import Adam


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import clear_output
from time import sleep
import os

Train_Dir = 'training.csv'
train_data = pd.read_csv(Train_Dir)  
train_data.fillna(method = 'ffill',inplace = True)
imag = []
for i in range(0,7049):
    img = train_data['Image'][i].split(' ')
    img = ['0' if x == '' else x for x in img]
    imag.append(img)
image_list = np.array(imag,dtype = 'float')
X_train = image_list.reshape(-1,96,96)
training = train_data.drop('Image',axis = 1)

y_train = []
for i in range(0,7049):
    y = training.iloc[i,:]
    y_train.append(y)
y_train = np.array(y_train,dtype = 'float')

# %%
X_train=np.expand_dims(X_train,axis=4)
print(X_train.shape)
# Out:
# (7049, 96, 96, 1)
# C:\Users\myson\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """Entry point for launching an IPython kernel.

# %%
hist = History()
epochs = 50
batch_size = 64

checkpointer = ModelCheckpoint(filepath='weights.final_2.hdf5', 
                               verbose=1, save_best_only=True)

## TODO: Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

hist_final = model.fit(X_train, y_train, validation_split=0.2,
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer, hist], verbose=1)


model.save('my_model2.h5')
# Out:
# WARNING:tensorflow:From C:\Users\myson\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\myson\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5639 samples, validate on 1410 samples
# Epoch 1/50
# 5639/5639 [==============================] - 78s 14ms/step - loss: 245.8790 - acc: 0.3040 - val_loss: 90.3874 - val_acc: 0.6674
#
# Epoch 00001: val_loss improved from inf to 90.38742, saving model to weights.final_2.hdf5
# Epoch 2/50
# 5639/5639 [==============================] - 81s 14ms/step - loss: 124.7445 - acc: 0.3435 - val_loss: 75.9740 - val_acc: 0.6830
#
# Epoch 00002: val_loss improved from 90.38742 to 75.97398, saving model to weights.final_2.hdf5
# Epoch 3/50
# 5639/5639 [==============================] - 79s 14ms/step - loss: 91.2895 - acc: 0.3907 - val_loss: 78.6404 - val_acc: 0.6752
#
# Epoch 00003: val_loss did not improve from 75.97398
# Epoch 4/50
# 5639/5639 [==============================] - 72s 13ms/step - loss: 74.5277 - acc: 0.4247 - val_loss: 52.6601 - val_acc: 0.6787
#
# Epoch 00004: val_loss improved from 75.97398 to 52.66014, saving model to weights.final_2.hdf5
# Epoch 5/50
# 5639/5639 [==============================] - 79s 14ms/step - loss: 59.7024 - acc: 0.4547 - val_loss: 45.6642 - val_acc: 0.6759
#
# Epoch 00005: val_loss improved from 52.66014 to 45.66424, saving model to weights.final_2.hdf5
# Epoch 6/50
# 5639/5639 [==============================] - 75s 13ms/step - loss: 41.7724 - acc: 0.4707 - val_loss: 51.1309 - val_acc: 0.6801
#
# Epoch 00006: val_loss did not improve from 45.66424
# Epoch 7/50
# 5639/5639 [==============================] - 71s 13ms/step - loss: 30.6177 - acc: 0.4746 - val_loss: 11.8485 - val_acc: 0.6879
#
# Epoch 00007: val_loss improved from 45.66424 to 11.84851, saving model to weights.final_2.hdf5
# Epoch 8/50
# 5639/5639 [==============================] - 67s 12ms/step - loss: 21.4630 - acc: 0.4848 - val_loss: 9.0664 - val_acc: 0.6908
#
# Epoch 00008: val_loss improved from 11.84851 to 9.06642, saving model to weights.final_2.hdf5
# Epoch 9/50
# 5639/5639 [==============================] - 65s 12ms/step - loss: 18.9738 - acc: 0.5098 - val_loss: 6.7863 - val_acc: 0.6887
#
# Epoch 00009: val_loss improved from 9.06642 to 6.78630, saving model to weights.final_2.hdf5
# Epoch 10/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 17.9716 - acc: 0.5317 - val_loss: 14.1206 - val_acc: 0.6865
#
# Epoch 00010: val_loss did not improve from 6.78630
# Epoch 11/50
# 5639/5639 [==============================] - 66s 12ms/step - loss: 16.8740 - acc: 0.5590 - val_loss: 6.7957 - val_acc: 0.6773
#
# Epoch 00011: val_loss did not improve from 6.78630
# Epoch 12/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 16.1270 - acc: 0.5717 - val_loss: 5.5739 - val_acc: 0.6766
#
# Epoch 00012: val_loss improved from 6.78630 to 5.57385, saving model to weights.final_2.hdf5
# Epoch 13/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 15.1030 - acc: 0.5930 - val_loss: 6.0115 - val_acc: 0.6816
#
# Epoch 00013: val_loss did not improve from 5.57385
# Epoch 14/50
# 5639/5639 [==============================] - 70s 12ms/step - loss: 14.6186 - acc: 0.6044 - val_loss: 5.6908 - val_acc: 0.6780
#
# Epoch 00014: val_loss did not improve from 5.57385
# Epoch 15/50
# 5639/5639 [==============================] - 65s 11ms/step - loss: 14.5998 - acc: 0.6166 - val_loss: 5.7402 - val_acc: 0.6794
#
# Epoch 00015: val_loss did not improve from 5.57385
# Epoch 16/50
# 5639/5639 [==============================] - 62s 11ms/step - loss: 13.9667 - acc: 0.6271 - val_loss: 7.5102 - val_acc: 0.6865
#
# Epoch 00016: val_loss did not improve from 5.57385
# Epoch 17/50
# 5639/5639 [==============================] - 63s 11ms/step - loss: 13.3453 - acc: 0.6304 - val_loss: 8.9559 - val_acc: 0.6837
#
# Epoch 00017: val_loss did not improve from 5.57385
# Epoch 18/50
# 5639/5639 [==============================] - 65s 11ms/step - loss: 13.5410 - acc: 0.6340 - val_loss: 5.4888 - val_acc: 0.6957
#
# Epoch 00018: val_loss improved from 5.57385 to 5.48885, saving model to weights.final_2.hdf5
# Epoch 19/50
# 5639/5639 [==============================] - 67s 12ms/step - loss: 12.8125 - acc: 0.6448 - val_loss: 5.4982 - val_acc: 0.6915
#
# Epoch 00019: val_loss did not improve from 5.48885
# Epoch 20/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 12.7923 - acc: 0.6647 - val_loss: 4.9820 - val_acc: 0.6972
#
# Epoch 00020: val_loss improved from 5.48885 to 4.98199, saving model to weights.final_2.hdf5
# Epoch 21/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 12.3446 - acc: 0.6648 - val_loss: 5.4156 - val_acc: 0.6993
#
# Epoch 00021: val_loss did not improve from 4.98199
# Epoch 22/50
# 5639/5639 [==============================] - 66s 12ms/step - loss: 12.1459 - acc: 0.6735 - val_loss: 4.8836 - val_acc: 0.6986
#
# Epoch 00022: val_loss improved from 4.98199 to 4.88362, saving model to weights.final_2.hdf5
# Epoch 23/50
# 5639/5639 [==============================] - 67s 12ms/step - loss: 12.3956 - acc: 0.6718 - val_loss: 11.5110 - val_acc: 0.7113
#
# Epoch 00023: val_loss did not improve from 4.88362
# Epoch 24/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 11.8804 - acc: 0.6877 - val_loss: 5.1449 - val_acc: 0.7092
#
# Epoch 00024: val_loss did not improve from 4.88362
# Epoch 25/50
# 5639/5639 [==============================] - 72s 13ms/step - loss: 11.2743 - acc: 0.6975 - val_loss: 6.8117 - val_acc: 0.7092
#
# Epoch 00025: val_loss did not improve from 4.88362
# Epoch 26/50
# 5639/5639 [==============================] - 71s 13ms/step - loss: 11.5260 - acc: 0.7062 - val_loss: 4.5792 - val_acc: 0.7099
#
# Epoch 00026: val_loss improved from 4.88362 to 4.57917, saving model to weights.final_2.hdf5
# Epoch 27/50
# 5639/5639 [==============================] - 71s 13ms/step - loss: 11.6610 - acc: 0.7063 - val_loss: 4.5969 - val_acc: 0.7156
#
# Epoch 00027: val_loss did not improve from 4.57917
# Epoch 28/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 11.1520 - acc: 0.7104 - val_loss: 5.9027 - val_acc: 0.7085
#
# Epoch 00028: val_loss did not improve from 4.57917
# Epoch 29/50
# 5639/5639 [==============================] - 69s 12ms/step - loss: 11.1989 - acc: 0.7095 - val_loss: 4.4641 - val_acc: 0.7213
#
# Epoch 00029: val_loss improved from 4.57917 to 4.46408, saving model to weights.final_2.hdf5
# Epoch 30/50
# 5639/5639 [==============================] - 79s 14ms/step - loss: 11.0521 - acc: 0.7168 - val_loss: 4.3782 - val_acc: 0.7184
#
# Epoch 00030: val_loss improved from 4.46408 to 4.37822, saving model to weights.final_2.hdf5
# Epoch 31/50
# 5639/5639 [==============================] - 70s 12ms/step - loss: 10.7841 - acc: 0.7205 - val_loss: 4.4484 - val_acc: 0.7255
#
# Epoch 00031: val_loss did not improve from 4.37822
# Epoch 32/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 10.8863 - acc: 0.7260 - val_loss: 4.4459 - val_acc: 0.7106
#
# Epoch 00032: val_loss did not improve from 4.37822
# Epoch 33/50
# 5639/5639 [==============================] - 65s 12ms/step - loss: 10.6226 - acc: 0.7281 - val_loss: 4.4890 - val_acc: 0.7184
#
# Epoch 00033: val_loss did not improve from 4.37822
# Epoch 34/50
# 5639/5639 [==============================] - 66s 12ms/step - loss: 10.7831 - acc: 0.7349 - val_loss: 4.5294 - val_acc: 0.7213
#
# Epoch 00034: val_loss did not improve from 4.37822
# Epoch 35/50
# 5639/5639 [==============================] - 65s 11ms/step - loss: 10.4101 - acc: 0.7393 - val_loss: 4.3095 - val_acc: 0.7298
#
# Epoch 00035: val_loss improved from 4.37822 to 4.30952, saving model to weights.final_2.hdf5
# Epoch 36/50
# 5639/5639 [==============================] - 65s 12ms/step - loss: 10.6367 - acc: 0.7317 - val_loss: 5.0247 - val_acc: 0.7092
#
# Epoch 00036: val_loss did not improve from 4.30952
# Epoch 37/50
# 5639/5639 [==============================] - 65s 11ms/step - loss: 10.2300 - acc: 0.7363 - val_loss: 4.5758 - val_acc: 0.7262
#
# Epoch 00037: val_loss did not improve from 4.30952
# Epoch 38/50
# 5639/5639 [==============================] - 65s 12ms/step - loss: 10.3038 - acc: 0.7429 - val_loss: 6.7773 - val_acc: 0.7248
#
# Epoch 00038: val_loss did not improve from 4.30952
# Epoch 39/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 10.3593 - acc: 0.7432 - val_loss: 4.7675 - val_acc: 0.7298
#
# Epoch 00039: val_loss did not improve from 4.30952
# Epoch 40/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 10.1553 - acc: 0.7507 - val_loss: 4.3951 - val_acc: 0.7241
#
# Epoch 00040: val_loss did not improve from 4.30952
# Epoch 41/50
# 5639/5639 [==============================] - 63s 11ms/step - loss: 9.9384 - acc: 0.7569 - val_loss: 5.0555 - val_acc: 0.7142
#
# Epoch 00041: val_loss did not improve from 4.30952
# Epoch 42/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 10.1475 - acc: 0.7489 - val_loss: 3.9790 - val_acc: 0.7355
#
# Epoch 00042: val_loss improved from 4.30952 to 3.97900, saving model to weights.final_2.hdf5
# Epoch 43/50
# 5639/5639 [==============================] - 65s 12ms/step - loss: 9.6501 - acc: 0.7567 - val_loss: 5.9326 - val_acc: 0.7404
#
# Epoch 00043: val_loss did not improve from 3.97900
# Epoch 44/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 10.0172 - acc: 0.7629 - val_loss: 4.0034 - val_acc: 0.7291
#
# Epoch 00044: val_loss did not improve from 3.97900
# Epoch 45/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 9.7014 - acc: 0.7615 - val_loss: 4.0613 - val_acc: 0.7199
#
# Epoch 00045: val_loss did not improve from 3.97900
# Epoch 46/50
# 5639/5639 [==============================] - 72s 13ms/step - loss: 9.6667 - acc: 0.7565 - val_loss: 4.5913 - val_acc: 0.7220
#
# Epoch 00046: val_loss did not improve from 3.97900
# Epoch 47/50
# 5639/5639 [==============================] - 68s 12ms/step - loss: 9.4692 - acc: 0.7592 - val_loss: 5.4980 - val_acc: 0.7220
#
# Epoch 00047: val_loss did not improve from 3.97900
# Epoch 48/50
# 5639/5639 [==============================] - 64s 11ms/step - loss: 9.8449 - acc: 0.7570 - val_loss: 4.4577 - val_acc: 0.7142
#
# Epoch 00048: val_loss did not improve from 3.97900
# Epoch 49/50
# 5639/5639 [==============================] - 67s 12ms/step - loss: 9.4216 - acc: 0.7649 - val_loss: 4.5176 - val_acc: 0.7255
#
# Epoch 00049: val_loss did not improve from 3.97900
# Epoch 50/50
# 5639/5639 [==============================] - 69s 12ms/step - loss: 9.6467 - acc: 0.7611 - val_loss: 4.3148 - val_acc: 0.7270
#
# Epoch 00050: val_loss did not improve from 3.97900

# %%
# Visualize the training and validation loss of the neural network
plt.plot(range(epochs), hist_final.history[
         'val_loss'], 'g-', label='Val Loss')
plt.plot(range(epochs), hist_final.history[
         'loss'], 'g--', label='Train Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#preparing test data
test_data = pd.read_csv('test.csv')
timag = []
for i in range(0,1783):
    timg = test_data['Image'][i].split(' ')
    timg = ['0' if x == '' else x for x in timg]
    
    timag.append(timg)
timage_list = np.array(timag,dtype = 'float')
X_test1 = timage_list.reshape(-1,96,96)
X_test=np.expand_dims(X_test1,axis=4)

y_test = model.predict(X_test)
fig = plt.figure(figsize=(10,10))

fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(10,19):
    ax = fig.add_subplot(3, 3, i -9, xticks=[], yticks=[])
    ax.imshow(X_test1[i],cmap='gray')
    for p in range(0, 30,2):
        ax.scatter( y_test[i][p],y_test[i][p+1],marker='o')
# Out:
# C:\Users\myson\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   # This is added back by InteractiveShellApp.init_path()
